# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_m = pd.read_parquet('D:/rohan/thesis/Projects/Machine_Learning/Data_2021/Parquet/170621-152712-0-1-12-1033-0.parquet')
df_p = pd.read_csv('D:/rohan/thesis/Projects/Machine_Learning/Data_2021/Toolpath/OP1030.csv',delimiter= ';')

# %%
plt.plot(df_p['X_TTP Q [mm]'])

# %%
plt.plot(df_m['12'])
