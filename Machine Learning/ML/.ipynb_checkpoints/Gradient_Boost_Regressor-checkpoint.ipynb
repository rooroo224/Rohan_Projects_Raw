# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import seaborn as sns
from numpy import cov
from scipy.stats import pearsonr
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.multioutput import MultiOutputRegressor
from sklearn.model_selection import RandomizedSearchCV
from sklearn.tree import export_graphviz
import pydot

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
np.set_printoptions(threshold=np.inf)

# %%
blocks = [1030, 2030, 3030]
#blocks = [1030, 2030, 3030, 4030, 5030, 6030, 7030]

dfss = []
for block in blocks:
    print(block)
    dfss.append(pd.read_csv('combined_df_'+str(block)+'.csv'))

df = pd.concat(dfss)
df.shape
# Out:
# 1030
# 2030
# 3030
# (1685106, 71)

# %%
columns = df.columns
columns
# Out:
# Index(['Unnamed: 0', 'Leading angle', 'Side tilt angle',
#        'Surface Contact point X', 'Surface contact point Y',
#        'Surface contact point z', 'Surface Orietation X',
#        'Surface Orietation Y', 'Surface Orietation Z', 'Tool Tip Point X',
#        'Tool Tip Point Y', 'Tool Tip Point Z', 'Tool Orientation X',
#        'Tool Orientation Y', 'Tool Orientation Z',
#        'Closes Point Distance (Surface Contact Point - Acquired TCP 1030 blade0)',
#        'time', 'MachineX', 'MachineY', 'MachineZ', 'MachineA', 'MachineC',
#        'LoadSpindle', 'TransfX', 'TransfY', 'TransfZ', 'TransfI', 'TransfJ',
#        'TransfK', 'executionDuration', 'previousExecutionDuration',
#        'relativeTimetoPreviousCall program number', 'timeStamp', 'Tool Length',
#        'Tool Radius', 'G54-X', 'G54-Y', 'G54-Z', 'G54-A', 'G54-C',
#        'ProgNumber', 'Blade', 'Fx_mean', 'Fy_mean', 'Fz_mean', 'Mz_mean',
#        'Fc_mean', 'Fa_mean', 'FcN_mean', 'Fres_mean', 'Fx_sigma', 'Fy_sigma',
#        'Fz_sigma', 'Mz_sigma', 'Fc_sigma', 'Fa_sigma', 'FcN_sigma',
#        'Fres_sigma', 'Fx_max', 'Fy_max', 'Fz_max', 'Mz_max', 'Fc_max',
#        'Fa_max', 'FcN_max', 'Fres_max', 'compensation_x', 'compensation_y',
#        'compensation_z', 'tcp_error',
#        'Closest Point Distance (Tool Tip Point Planning - Tool Tip Point Acquired Blade 0)'],
#       dtype='object')

# %%
del_col = ['Unnamed: 0']
for column in columns:
    if(df[column].isnull().values.any()==True):
        print(column,df[column].isnull().values.any())
        del_col.append(column)
# Out:
# Closes Point Distance (Surface Contact Point - Acquired TCP 1030 blade0) True
# Closest Point Distance (Tool Tip Point Planning - Tool Tip Point Acquired Blade 0) True

# %%
df = df.drop(columns =del_col)
df.shape
# Out:
# (1685106, 68)

# %%
columns = df.columns
df.describe()
# Out:
#        Leading angle  Side tilt angle  Surface Contact point X  \
# count   1.685106e+06     1.685106e+06             1.685106e+06
# mean   -5.405271e-02     1.412285e+00            -4.704189e+00
# std     9.490437e-01     1.911781e-01             1.693196e+01
# min    -1.967589e+00     0.000000e+00            -2.935467e+01
# 25%    -9.670210e-01     1.396517e+00            -2.040551e+01
# 50%     1.570100e-02     1.501793e+00            -5.617261e+00
# 75%     6.471000e-01     1.525919e+00             1.096769e+01
# max     1.784306e+00     1.593057e+00             2.558036e+01
#
#        Surface contact point Y  Surface contact point z  Surface Orietation X  \
# count             1.685106e+06             1.685106e+06          1.685106e+06
# mean    -7.198045e-03  4.892923e-01
# std      3.982917e-04  5.433146e-01
# min     -1.000953e-02  1.279893e-02
# 25%     -7.464696e-03  2.230373e-01
# 50%     -7.251987e-03  2.770172e-01
# 75%     -6.914112e-03  4.230517e-01
# max     -6.116251e-03  2.987454e+00

# %%
plot_range = np.arange(200000,320000)
columns = df.columns
index = 0
for column_name in columns:
    index = index+1
    plt.title(column_name)
    plt.plot(df[column_name].iloc[plot_range])
    plt.figure(index)
    plt.pause(0.3)

# %%
co_variance = cov(df, rowvar=False)
df_cov = pd.DataFrame(co_variance, columns=df.columns)
df_cov.set_index(columns)
# Out:
#                                            Leading angle  Side tilt angle  \
# Leading angle                               9.006840e-01    -1.135352e-02
# Side tilt angle                            -1.135352e-02     3.654906e-02
# Surface Contact point X                     7.183442e-01     3.377690e-01
# Surface contact point Y                    -2.227559e-01    -5.989478e-01
# Surface contact point z                    -1.906294e-01     2.348679e-01
# Surface Orietation X                        3.696523e-01     9.782814e-03
# Surface Orietation Y                        5.034494e-03    -3.641709e-02
# Surface Orietation Z                       -6.403953e-01     2.387204e-02
# Tool Tip Point X                            2.748805e+00     3.348913e-01
# Tool Tip Point Y                           -1.734794e-01    -9.585018e-01
# Tool Tip Point Z                           -3.880449e+00     3.083376e-01
# Tool Orientation X                          3.135693e-02     8.674917e-03
# Tool Orientation Y                         -2.177627e-03    -2.563157e-03
# Tool Orientation Z                         -2.540645e-02     5.527245e-03
# time                                       -8.388245e-01     3.962801e+00
# MachineX                                   -3.060830e+00     2.011084e+00
# MachineY                                   -5.729922e-01    -5.733723e-01
# MachineZ                                   -3.742770e+00    -2.618693e-01
# MachineA                                   -1.148734e+00    -5.436538e-02
# MachineC                                    5.925864e-02    -1.428344e-01
# LoadSpindle                                 2.808084e-04    -4.253420e-03
# TransfX                                    -2.866360e-01    -3.455848e-01
# TransfY                                     1.339705e-02    -7.970171e-03
# TransfZ                                    -3.941480e+00     3.298934e-01
# TransfI                                    -1.501033e-03     1.473440e-04
# TransfJ                                    -4.343168e-03    -4.430247e-04
# TransfK                                    -1.201476e-01    -2.761346e-03
# executionDuration                          -4.345674e-06    -2.784762e-05
# previousExecutionDuration                  -4.211138e-06    -2.672570e-05
# relativeTimetoPreviousCall program number  -1.319045e-05    -3.313105e-05
# timeStamp                                   1.008660e+03     2.803568e+03
# Tool Length                                -3.370995e-03    -7.324727e-03
# Tool Radius                                 0.000000e+00     0.000000e+00
# G54-X                                       0.000000e+00     0.000000e+00
# G54-Y                                       0.000000e+00     0.000000e+00
# G54-Z                                      -7.828849e-18     3.145118e-17
# G54-A                                      -1.845650e-01    -3.018706e-01
# G54-C                                       0.000000e+00     0.000000e+00
# ProgNumber                                  2.249348e+01     6.773414e+01
# Blade                                       1.519349e-01     1.925997e-01
# Fx_mean                                    -8.797501e-01     4.343211e-01
# Fy_mean                                    -8.232394e-01     5.031322e-01
# Fz_mean                                    -2.910297e-02     1.048291e-02
# Mz_mean                                    -6.330181e-04     3.930703e-04
# Fc_mean                                    -1.055030e-01     6.551171e-02
# Fa_mean                                    -1.365531e+00     7.837354e-01
# FcN_mean                                   -1.342842e+00     7.741284e-01
# Fres_mean                                  -1.364238e+00     7.794908e-01
# Fx_sigma                                   -7.876098e-01     5.164240e-01
# Fy_sigma                                   -8.159059e-01     6.089250e-01
# Fz_sigma                                   -3.274279e-02     1.346030e-02
# Mz_sigma                                   -8.601376e-04     4.546745e-04
# Fc_sigma                                   -1.433563e-01     7.577909e-02
# Fa_sigma                                   -9.234082e-01     6.825286e-01
# FcN_sigma                                  -9.355838e-01     6.825753e-01
# Fres_sigma                                 -9.144068e-01     6.648185e-01
# Fx_max                                     -3.003616e+00     1.968579e+00
# Fy_max                                     -3.961061e+00     2.378706e+00
# Fz_max                                     -1.024859e-01     4.023613e-02
# Mz_max                                     -5.596521e-03     2.872024e-03
# Fc_max                                     -9.327536e-01     4.786706e-01
# Fa_max                                     -4.604085e+00     2.721587e+00
# FcN_max                                    -4.607071e+00     2.721135e+00
# Fres_max                                   -4.589881e+00     2.687837e+00
# compensation_x                             -2.283859e-04    -1.953476e-05
# compensation_y                              6.334758e-05     4.444290e-05
# compensation_z                              8.064846e-05     2.610155e-05
# tcp_error                                   2.761537e-02    -8.345648e-02
#
#                                            Surface Contact point X  \
# Leading angle                                         7.183442e-01
# Side tilt angle                                       3.377690e-01
# Surface Contact point X                               2.866914e+02
# Surface contact point Y                               4.612103e+01
# Surface contact point z                               1.750836e+02
# Surface Orietation X                                  4.064441e+00
# Surface Orietation Y                                 -1.311574e+00
# Surface Orietation Z                                  1.788594e+00
# Tool Tip Point X                                      2.921071e+02
# Tool Tip Point Y                                      4.254813e+01
# Tool Tip Point Z                                      1.804001e+02
# Tool Orientation X                                    3.170495e+00
# Tool Orientation Y                                   -6.298221e-01
# Tool Orientation Z                                    9.262227e-01
# time                                                 -4.264977e+00
# MachineX                                             -2.081275e+02
# MachineY                                             -1.782141e+02
# MachineZ                                              8.479607e+00
# MachineA                                              1.784246e+00
# MachineC                                              6.912121e+00
# LoadSpindle                                           2.556912e-01
# TransfX                                               1.013802e+01
# TransfY                                               2.730997e+00
# TransfZ                                               1.824825e+02
# TransfI                                              -5.214076e-02
# TransfJ                                              -7.448230e-02
# TransfK                                              -9.470198e-01
# executionDuration                                     9.590067e-04
# previousExecutionDuration                             9.029807e-04
# relativeTimetoPreviousCall program number             9.385887e-04
# timeStamp                                            -1.181390e+05
# Tool Length                                           3.288361e-01
# Tool Radius                                           0.000000e+00
# G54-X                                                 0.000000e+00
# G54-Y                                                 0.000000e+00
# G54-Z                                                -3.304123e-16
# G54-A                                                 6.388732e+00
# G54-C                                                 0.000000e+00
# ProgNumber                                           -2.725633e+03
# Blade                                                -1.972830e+00
# Fx_mean                                              -5.715151e+00
# Fy_mean                                              -8.387091e+00
# Fz_mean                                              -1.263973e-01
# Mz_mean                                              -5.258985e-03
# Fc_mean                                              -8.764975e-01
# Fa_mean                                              -1.246768e+01
# FcN_mean                                             -1.240977e+01
# Fres_mean                                            -1.241141e+01
# Fx_sigma                                             -1.050440e+01
# Fy_sigma                                             -1.436939e+01
# Fz_sigma                                             -1.745862e-01
# Mz_sigma                                             -6.694337e-03
# Fc_sigma                                             -1.115723e+00
# Fa_sigma                                             -1.628167e+01
# FcN_sigma                                            -1.617783e+01
# Fres_sigma                                           -1.541241e+01
# Fx_max                                               -3.988737e+01
# Fy_max                                               -6.030081e+01
# Fz_max                                               -4.721846e-01
# Mz_max                                               -4.848873e-02
# Fc_max                                               -8.081454e+00
# Fa_max                                               -6.359371e+01
# FcN_max                                              -6.357996e+01
# Fres_max                                             -6.104778e+01
# compensation_x                                       -6.792989e-04
# compensation_y                                        3.689667e-03
# compensation_z                                       -2.793226e-03
# tcp_error                                            -2.913547e+00
#
#                                            Surface contact point Y  \
# Leading angle                                        -2.227559e-01
# Side tilt angle                                      -5.989478e-01
# Surface Contact point X                               4.612103e+01
# Surface contact point Y                               1.149687e+02
# Surface contact point z                               3.376301e+01
# Surface Orietation X                                  2.632949e-01
# Surface Orietation Y                                  6.863334e-01
# Surface Orietation Z                                  1.488816e-01
# Tool Tip Point X                                      4.438720e+01
# Tool Tip Point Y                                      9.627460e+01
# Tool Tip Point Z                                      2.958417e+01
# Tool Orientation X                                    3.286642e-01
# Tool Orientation Y                                   -1.616473e-02
# Tool Orientation Z                                   -3.827757e-02
# time                                                 -6.039259e+01
# MachineX                                             -2.386027e+02
# MachineY                                              3.364354e+01
# MachineZ                                              4.017170e+01
# MachineA                                              1.685525e+01
# MachineC                                              1.084799e+01
# LoadSpindle                                           7.491132e-01
# TransfX                                               2.351436e+01
# TransfY                                               1.164049e+01
# TransfZ                                               2.960893e+01
# TransfI                                              -2.291037e-02
# TransfJ                                              -2.209739e-02
# TransfK                                              -7.644406e-01
# executionDuration                                     2.454722e-03
# previousExecutionDuration                             2.321938e-03
# relativeTimetoPreviousCall program number             2.466620e-03
# timeStamp                                            -3.438171e+05
# Tool Length                                           1.015725e+00
# Tool Radius                                           0.000000e+00
# G54-X                                                 0.000000e+00
# G54-Y                                                 0.000000e+00
# G54-Z                                                 2.018898e-15
# G54-A                                                 1.950917e+01
# G54-C                                                 0.000000e+00
# ProgNumber                                           -7.669322e+03
# Blade                                                -7.145315e+00
# Fx_mean                                               1.347635e+00
# Fy_mean                                               2.481331e+00
# Fz_mean                                               5.755466e-02
# Mz_mean                                              -5.546249e-03
# Fc_mean                                              -9.243749e-01
# Fa_mean                                               1.806475e+00
# FcN_mean                                              1.756701e+00
# Fres_mean                                             1.717381e+00
# Fx_sigma                                             -5.366683e+00
# Fy_sigma                                             -5.355065e+00
# Fz_sigma                                              4.030653e-02
# Mz_sigma                                             -5.197172e-03
# Fc_sigma                                             -8.661954e-01
# Fa_sigma                                             -8.167002e+00
# FcN_sigma                                            -7.950837e+00
# Fres_sigma                                           -7.781769e+00
# Fx_max                                               -2.073806e+01
# Fy_max                                               -2.059394e+01
# Fz_max                                                2.636103e-01
# Mz_max                                               -3.039070e-02
# Fc_max                                               -5.065117e+00
# Fa_max                                               -1.959267e+01
# FcN_max                                              -1.953100e+01
# Fres_max                                             -1.915598e+01
# compensation_x                                        2.634607e-03
# compensation_y                                       -4.313502e-03
# compensation_z                                       -3.493786e-03
# tcp_error                                             1.130363e+00
#
#                                            Surface contact point z  \
# Leading angle                                        -1.906294e-01
# Side tilt angle                                       2.348679e-01
# Surface Contact point X                               1.750836e+02
# Surface contact point Y                               3.376301e+01
# Surface contact point z                               1.092148e+02
# Surface Orietation X                                  2.120745e+00
# Surface Orietation Y                                 -7.808624e-01
# Surface Orietation Z                                  1.739086e+00
# Tool Tip Point X                                      1.761520e+02
# Tool Tip Point Y                                      2.852902e+01
# Tool Tip Point Z                                      1.155058e+02
# Tool Orientation X                                    1.917558e+00
# Tool Orientation Y                                   -3.710184e-01
# Tool Orientation Z                                    5.858390e-01
# time                                                 -5.620542e+00
# MachineX                                             -1.359892e+02
# MachineY                                             -1.054922e+02
# MachineZ                                              9.148986e+00
# MachineA                                              3.500740e+00
# MachineC                                              4.603349e+00
# LoadSpindle                                           1.820194e-01
# TransfX                                               6.667507e+00
# TransfY                                               2.202239e+00
# TransfZ                                               1.169238e+02
# TransfI                                              -2.674556e-02
# TransfJ                                              -4.268618e-02
# TransfK                                              -5.992762e-01
# executionDuration                                     6.505398e-04
# previousExecutionDuration                             6.127812e-04
# relativeTimetoPreviousCall program number             6.145172e-04
# timeStamp                                            -8.100029e+04
# Tool Length                                           2.292869e-01
# Tool Radius                                           0.000000e+00
# G54-X                                                 0.000000e+00
# G54-Y                                                 0.000000e+00
# G54-Z                                                 1.208197e-16
# G54-A                                                 4.418850e+00
# G54-C                                                 0.000000e+00
# ProgNumber                                           -1.851761e+03
# Blade                                                -1.424679e+00
# Fx_mean                                              -1.344511e+00
# Fy_mean                                              -2.653026e+00
# Fz_mean                                              -1.337388e-02
# Mz_mean                                              -1.740270e-03
# Fc_mean                                              -2.900450e-01
# Fa_mean                                              -3.844564e+00
# FcN_mean                                             -3.857169e+00
# Fres_mean                                            -3.826775e+00
# Fx_sigma                                             -4.286720e+00
# Fy_sigma                                             -6.278015e+00
# Fz_sigma                                             -2.983536e-02
# Mz_sigma                                             -2.094621e-03
# Fc_sigma                                             -3.491035e-01
# Fa_sigma                                             -7.240906e+00
# FcN_sigma                                            -7.162599e+00
# Fres_sigma                                           -6.761423e+00
# Fx_max                                               -1.643115e+01
# Fy_max                                               -2.667607e+01
# Fz_max                                               -4.317405e-02
# Mz_max                                               -1.637738e-02
# Fc_max                                               -2.729564e+00
# Fa_max                                               -2.689408e+01
# FcN_max                                              -2.688180e+01
# Fres_max                                             -2.544322e+01
# compensation_x                                       -1.543286e-04
# compensation_y                                        1.973223e-03
# compensation_z                                       -1.913311e-03
# tcp_error                                            -1.821576e+00
#
#                                            Surface Orietation X  \
# Leading angle                                      3.696523e-01
# Side tilt angle                                    9.782814e-03
# Surface Contact point X                            4.064441e+00
# Surface contact point Y                            2.632949e-01
# Surface contact point z                            2.120745e+00
# Surface Orietation X                               3.148422e-01
# Surface Orietation Y                              -2.555775e-02
# Surface Orietation Z                              -3.064155e-01
# TransfY                                            2.239674e-02
# TransfZ                                           -9.879692e-01
# TransfI                                            7.516896e-05
# TransfJ                                            1.214756e-03
# TransfK                                           -3.468912e-03
# executionDuration                                  2.652473e-05
# previousExecutionDuration                          2.557244e-05
# relativeTimetoPreviousCall program number          2.944747e-05
# timeStamp                                         -2.681325e+03
# Tool Length                                        7.052896e-03
# Tool Radius                                        0.000000e+00
# G54-X                                              0.000000e+00
# G54-Y                                              0.000000e+00
# G54-Z                                             -1.511251e-17
# G54-A                                              2.756194e-01
# G54-C                                              0.000000e+00
# ProgNumber                                        -6.433625e+01
# Blade                                             -1.717658e-01
# Fx_mean                                           -2.474959e-01
# Fy_mean                                           -2.789712e-01
# Fz_mean                                           -6.053257e-03
# Mz_mean                                           -2.270479e-04
# Fc_mean                                           -3.784131e-02
# Fa_mean                                           -4.369917e-01
# FcN_mean                                          -4.314215e-01
# Fres_mean                                         -4.347307e-01
# Fx_sigma                                          -2.815913e-01
# Fy_sigma                                          -3.242720e-01
# Fz_sigma                                          -7.674505e-03
# Mz_sigma                                          -2.594812e-04
# Fc_sigma                                          -4.324687e-02
# Fa_sigma                                          -3.644408e-01
# FcN_sigma                                         -3.650393e-01
# Fres_sigma                                        -3.588892e-01
# Fx_max                                            -1.067342e+00
# Fy_max                                            -1.263728e+00
# Fz_max                                            -2.241790e-02
# Mz_max                                            -1.631224e-03
# Fc_max                                            -2.718707e-01
# Fa_max                                            -1.451025e+00
# FcN_max                                           -1.451493e+00
# Fres_max                                          -1.453132e+00
# compensation_x                                     2.239833e-05
# compensation_y                                    -6.262112e-05
# compensation_z                                    -2.023223e-05
# tcp_error                                          8.850410e-02
#
#                                            Surface Orietation Z  \
# Leading angle                                     -6.403953e-01
# Side tilt angle                                    2.387204e-02
# Surface Contact point X                            1.788594e+00
# Surface contact point Y                            1.488816e-01
# Surface contact point z                            1.739086e+00
# Surface Orietation X                              -3.064155e-01
# Surface Orietation Y                              -4.001874e-02
# Surface Orietation Z                               6.295039e-01
# Tool Tip Point X                                  -4.428929e-02
# Tool Tip Point Y                                  -6.118991e-02
# Tool Tip Point Z                                   5.320632e+00
# Tool Orientation X                                -9.189970e-04
# Tool Orientation Y                                -4.793892e-03
# Tool Orientation Z                                 3.288869e-02
# time                                              -1.606181e-02
# MachineX                                           2.167807e+00
# MachineY                                          -4.485496e-01
# MachineZ                                           3.621774e+00
# MachineA                                           1.305661e+00
# MachineC                                           1.227888e-02
# LoadSpindle                                       -7.535897e-05
# TransfX                                            1.222762e-01
# TransfY                                           -1.162418e-02
# TransfZ                                            5.462648e+00
# TransfI                                            1.231324e-03
# TransfJ                                            1.829018e-03
# TransfK                                            6.006523e-02
# executionDuration                                  1.408281e-06
# previousExecutionDuration                          1.304234e-06
# relativeTimetoPreviousCall program number         -4.164610e-08
# timeStamp                                          1.200146e+02
# Tool Length                                       -7.397191e-05
# Tool Radius                                        0.000000e+00
# G54-X                                              0.000000e+00
# G54-Y                                              0.000000e+00
# G54-Z                                             -7.340194e-18
# G54-A                                              7.344849e-02
# G54-A                                          6.095197e+00      2.038147e+01
# G54-C                                          0.000000e+00      0.000000e+00
# ProgNumber                                    -2.572320e+03     -8.064954e+03
# Blade                                         -1.919582e+00     -7.383346e+00
# Fx_mean                                       -7.367852e+00     -8.282605e-01
# Fy_mean                                       -9.578388e+00     -4.916713e-02
# Fz_mean                                       -1.875683e-01      4.412202e-03
# Mz_mean                                       -6.258725e-03     -7.501365e-03
# Fc_mean                                       -1.043121e+00     -1.250227e+00
# Fa_mean                                       -1.473089e+01     -2.118021e+00
# FcN_mean                                      -1.462764e+01     -2.120203e+00
# Fres_mean                                     -1.467629e+01     -2.186288e+00
# Fx_sigma                                      -1.197576e+01     -7.930298e+00
# Fy_sigma                                      -1.568907e+01     -8.391083e+00
# Fz_sigma                                      -2.410046e-01     -2.811694e-02
# Mz_sigma                                      -8.021673e-03     -7.480770e-03
# Fc_sigma                                      -1.336945e+00     -1.246795e+00
# Fa_sigma                                      -1.790358e+01     -1.156803e+01
# FcN_sigma                                     -1.782973e+01     -1.135316e+01
# Fres_sigma                                    -1.695817e+01     -1.109285e+01
# Fx_max                                        -4.566916e+01     -3.062882e+01
# Fy_max                                        -6.827539e+01     -3.258205e+01
# Fz_max                                        -6.822053e-01      5.920569e-02
# Mz_max                                        -5.674231e-02     -4.499983e-02
# Fc_max                                        -9.457052e+00     -7.499971e+00
# Fa_max                                        -7.233999e+01     -3.333025e+01
# FcN_max                                       -7.233706e+01     -3.326564e+01
# Fres_max                                      -6.953367e+01     -3.271076e+01
# compensation_x                                -1.420441e-03      2.831420e-03
# compensation_y                                 4.187075e-03     -4.593000e-03
# compensation_z                                -2.524249e-03     -3.690169e-03
# tcp_error                                     -3.212015e+00      1.660830e+00
#
#                                            Tool Tip Point Z  \
# Leading angle                                 -3.880449e+00
# Side tilt angle                                3.083376e-01
# Surface Contact point X                        1.804001e+02
# Surface contact point Y                        2.958417e+01
# Surface contact point z                        1.155058e+02
# Surface Orietation X                           2.902153e-01
# Surface Orietation Y                          -9.628581e-01
# Surface Orietation Z                           5.320632e+00
# Tool Tip Point X                               1.712191e+02
# Tool Tip Point Y                               2.898079e+01
# Tool Tip Point Z                               1.437176e+02
# Tool Orientation X                             1.846665e+00
# Tool Orientation Y                            -3.822238e-01
# Tool Orientation Z                             7.453805e-01
# time                                          -6.881219e+00
# MachineX                                      -1.219355e+02
# MachineY                                      -1.060273e+02
# MachineZ                                       3.058862e+01
# MachineA                                       1.084431e+01
# MachineC                                       4.597391e+00
# LoadSpindle                                    1.817663e-01
# TransfX                                        7.512147e+00
# TransfY                                        2.089723e+00
# TransfZ                                        1.459303e+02
# TransfI                                       -1.969903e-02
# TransfJ                                       -2.993087e-02
# TransfK                                       -2.446776e-01
# executionDuration                              6.654872e-04
# previousExecutionDuration                      6.281433e-04
# relativeTimetoPreviousCall program number      6.187156e-04
# timeStamp                                     -8.105244e+04
# Tool Length                                    2.292418e-01
# Tool Radius                                    0.000000e+00
# G54-X                                          0.000000e+00
# G54-Y                                          0.000000e+00
# G54-Z                                         -6.473648e-16
# G54-A                                          4.875752e+00
# G54-C                                          0.000000e+00
# ProgNumber                                    -1.858529e+03
# Blade                                         -1.888953e+00
# Fx_mean                                        2.314310e+00
# Fy_mean                                        5.550431e-01
# Fz_mean                                        1.142354e-01
# Mz_mean                                        9.671772e-04
# Fc_mean                                        1.611962e-01
# Fa_mean                                        1.683698e+00
# FcN_mean                                       1.580329e+00
# Fres_mean                                      1.704563e+00
# Fx_sigma                                      -8.680272e-01
# Fy_sigma                                      -2.990491e+00
# Fz_sigma                                       1.126551e-01
# Mz_sigma                                       1.555673e-03
# Fc_sigma                                       2.592789e-01
# Fa_sigma                                      -3.379249e+00
# FcN_sigma                                     -3.253639e+00
# Fres_sigma                                    -2.908855e+00
# Fx_max                                        -3.864970e+00
# Fy_max                                        -1.052737e+01
# Fz_max                                         3.942394e-01
# Mz_max                                         7.506569e-03
# Fc_max                                         1.251095e+00
# Fa_max                                        -8.333454e+00
# FcN_max                                       -8.308040e+00
# Fres_max                                      -6.798302e+00
# compensation_x                                 1.128478e-03
# compensation_y                                 1.704063e-03
# compensation_z                                -2.422270e-03
# tcp_error                                     -2.171266e+00
#
#                                            Tool Orientation X  \
# Leading angle                                    3.135693e-02
# Side tilt angle                                  8.674917e-03
# Surface Contact point X                          3.170495e+00
# Surface contact point Y                          3.286642e-01
# Surface contact point z                          1.917558e+00
# Surface Orietation X                             5.843991e-02
# Surface Orietation Y                            -2.190422e-02
# Surface Orietation Z                            -9.189970e-04
# Tool Tip Point X                                 3.266481e+00
# Tool Tip Point Y                                 2.857762e-01
# Tool Tip Point Z                                 1.846665e+00
# Tool Orientation X                               4.280267e-02
# Tool Orientation Y                              -9.266348e-03
# Tool Orientation Z                               1.218340e-02
# time                                             1.542892e+00
# MachineX                                        -2.528888e+00
# MachineY                                        -1.843677e+00
# MachineZ                                        -1.744000e-01
# MachineA                                         2.844805e-02
# MachineC                                         5.832341e-02
# LoadSpindle                                      2.418443e-03
# TransfX                                          1.670306e-02
# TransfY                                          4.442043e-02
# TransfZ                                          1.860534e+00
# TransfI                                         -4.223776e-04
# TransfJ                                         -1.255618e-03
# TransfK                                         -7.517931e-03
# executionDuration                                3.277865e-06
# previousExecutionDuration                        2.822652e-06
# relativeTimetoPreviousCall program number        3.976246e-06
# timeStamp                                       -1.049240e+03
# Tool Length                                      3.447982e-03
# Tool Radius                                      0.000000e+00
# G54-X                                            0.000000e+00
# G54-Y                                            0.000000e+00
# G54-Z                                           -9.376849e-19
# G54-A                                            3.044298e-03
# G54-C                                            0.000000e+00
# ProgNumber                                      -2.154517e+01
# Blade                                            3.217651e-02
# Fx_mean                                         -6.294561e-02
# Fy_mean                                         -9.203212e-02
# Fz_mean                                         -1.733325e-03
# Mz_mean                                         -5.883912e-05
# Fc_mean                                         -9.806520e-03
# Fa_mean                                         -1.360107e-01
# FcN_mean                                        -1.353409e-01
# Fres_mean                                       -1.357772e-01
# Fx_sigma                                        -1.122385e-01
# Fy_sigma                                        -1.539860e-01
# Fz_sigma                                        -2.188883e-03
# Mz_sigma                                        -8.380226e-05
# Fc_sigma                                        -1.396704e-02
# Fa_sigma                                        -1.739436e-01
# FcN_sigma                                       -1.728865e-01
# Fres_sigma                                      -1.654847e-01
# Fx_max                                          -4.278398e-01
# Fy_max                                          -6.581717e-01
# Fz_max                                          -5.815275e-03
# Mz_max                                          -6.317992e-04
# Fc_max                                          -1.052999e-01
# Fa_max                                          -7.015508e-01
# FcN_max                                         -7.008381e-01
# Fres_max                                        -6.735951e-01
# compensation_x                                  -2.275491e-05
# compensation_y                                   3.965848e-05
# ...
# Fa_max                                     9.666849e+01  5.892716e+02
# FcN_max                                    9.663256e+01  5.892022e+02
# Fres_max                                   9.547964e+01  5.807649e+02
# compensation_x                             5.611035e-05  3.933801e-04
# compensation_y                             1.415313e-04 -2.574915e-04
# compensation_z                             1.872520e-04  9.014387e-04
# tcp_error                                 -1.086423e+00 -5.802050e+00
#
#                                                 FcN_max      Fres_max  \
# Leading angle                             -4.607071e+00 -4.589881e+00
# Side tilt angle                            2.721135e+00  2.687837e+00
# Surface Contact point X                   -6.357996e+01 -6.104778e+01
# Surface contact point Y                   -1.953100e+01 -1.915598e+01
# Surface contact point z                   -2.688180e+01 -2.544322e+01
# Surface Orietation X                      -2.124527e+00 -2.053537e+00
# Surface Orietation Y                      -1.451493e+00 -1.453132e+00
# Surface Orietation Z                       3.263737e+00  3.276378e+00
# Tool Tip Point X                          -7.233706e+01 -6.953367e+01
# Tool Tip Point Y                          -3.326564e+01 -3.271076e+01
# Tool Tip Point Z                          -8.308040e+00 -6.798302e+00
# Tool Orientation X                        -7.008381e-01 -6.735951e-01
# Tool Orientation Y                         2.817683e-01  2.740981e-01
# Tool Orientation Z                         3.322976e-02  3.977737e-02
# time                                       7.106887e+02  7.000186e+02
# MachineX                                   9.310074e+01  9.132167e+01
# MachineY                                   3.412477e+01  3.236369e+01
# MachineZ                                   2.822146e+00  3.041114e+00
# MachineA                                   7.967473e+00  7.884534e+00
# MachineC                                  -1.887112e+02 -1.885425e+02
# LoadSpindle                                3.079463e-01  3.051567e-01
# TransfX                                   -4.153315e+02 -4.159047e+02
# TransfY                                    3.298005e+01  3.413812e+01
# TransfZ                                   -6.246074e+00 -4.740692e+00
# TransfI                                    4.583615e-03  3.757732e-03
# TransfJ                                    1.858342e-02  1.792520e-02
# TransfK                                    5.853756e-01  5.417983e-01
# executionDuration                          8.334271e-04  8.209290e-04
# previousExecutionDuration                  4.534135e-04  4.549147e-04
# relativeTimetoPreviousCall program number  1.833071e-03  1.743451e-03
# timeStamp                                  2.514023e+04  2.457229e+04
# Tool Length                               -5.571165e-01 -5.582408e-01
# Tool Radius                                0.000000e+00  0.000000e+00
# G54-X                                      0.000000e+00  0.000000e+00
# G54-Y                                      0.000000e+00  0.000000e+00
# G54-Z                                      1.461335e-15  1.431056e-15
# G54-A                                     -3.270140e+02 -3.276869e+02
# G54-C                                      0.000000e+00  0.000000e+00
# ProgNumber                                 9.272660e+02  9.147895e+02
# Blade                                      3.254754e+02  3.261454e+02
# MachineC                                    -4.985820e-04  8.454366e-01
# LoadSpindle                                 -2.854013e-05  9.840421e-03
# TransfX                                     -1.006113e-03  2.120649e+00
# TransfY                                     -4.096138e-04 -2.337917e-02
# TransfZ                                     -2.446562e-03 -2.276421e+00
# TransfI                                      7.802363e-07 -6.260577e-04
# TransfJ                                      6.956153e-07  7.721064e-04
# TransfK                                      2.796065e-05  5.227377e-02
# executionDuration                           -8.334885e-08  4.050442e-05
# previousExecutionDuration                   -7.881128e-08  3.863697e-05
# relativeTimetoPreviousCall program number   -8.367782e-08  5.873311e-05
# timeStamp                                    1.311521e+01 -6.109530e+03
# Tool Length                                 -4.021849e-05  1.987285e-02
# Tool Radius                                  0.000000e+00  0.000000e+00
# G54-X                                        0.000000e+00  0.000000e+00
# G54-Y                                        0.000000e+00  0.000000e+00
# G54-Z                                        3.452633e-20 -4.769702e-17
# G54-A                                       -7.961523e-04  1.472644e+00
# G54-C                                        0.000000e+00  0.000000e+00
# ProgNumber                                   2.870294e-01 -1.405632e+02
# Blade                                        3.328185e-04 -1.240528e+00
# Fx_mean                                     -4.116649e-05 -9.699777e-01
# Fy_mean                                     -4.273666e-05 -1.129720e+00
# Fz_mean                                     -2.916345e-06 -2.366212e-02
# Mz_mean                                      1.956707e-07 -8.746125e-04
# Fc_mean                                      3.261178e-05 -1.457688e-01
# Fa_mean                                     -1.699702e-05 -1.747942e+00
# FcN_mean                                    -1.480455e-05 -1.726717e+00
# Fres_mean                                   -1.496692e-05 -1.738835e+00
# Fx_sigma                                     2.165749e-04 -1.113153e+00
# Fy_sigma                                     2.530596e-04 -1.306075e+00
# Fz_sigma                                    -2.196482e-06 -3.020588e-02
# Mz_sigma                                     1.798868e-07 -1.023056e-03
# Fc_sigma                                     2.998113e-05 -1.705093e-01
# Fa_sigma                                     3.497395e-04 -1.454005e+00
# FcN_sigma                                    3.411133e-04 -1.454835e+00
# Fres_sigma                                   3.313701e-04 -1.427811e+00
# Fx_max                                       8.872046e-04 -4.220049e+00
# Fy_max                                       9.090387e-04 -4.983502e+00
# Fz_max                                      -1.359856e-05 -8.946051e-02
# Mz_max                                       1.123512e-06 -6.518538e-03
# Fc_max                                       1.872520e-04 -1.086423e+00
# Fa_max                                       9.014387e-04 -5.802050e+00
# FcN_max                                      8.981308e-04 -5.800060e+00
# Fres_max                                     8.693099e-04 -5.768558e+00
# compensation_x                              -1.392827e-07  5.678854e-05
# compensation_y                               1.767571e-07 -1.694577e-04
# compensation_z                               1.586363e-07 -4.210834e-05
# tcp_error                                   -4.210834e-05  2.951907e-01

# %%
corr = np.empty((len(columns),len(columns)))

for i, column1 in enumerate(columns):
    for j,column2 in enumerate(columns):
        corr[i,j] = pearsonr(df[column1],df[column2])[0]
# Out:
# /opt/conda/lib/python3.7/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())

# %%
df_corr = pd.DataFrame(corr, columns=df.columns)
df_corr.set_index(columns)
# Out:
#                                            Leading angle  Side tilt angle  \
# Leading angle                                   1.000000        -0.062576
# Side tilt angle                                -0.062576         1.000000
# Surface Contact point X                         0.044703         0.104346
# Surface contact point Y                        -0.021890        -0.292187
# Surface contact point z                        -0.019220         0.117556
# Surface Orietation X                            0.694162         0.091197
# Surface Orietation Y                            0.023494        -0.843636
# Surface Orietation Z                           -0.850477         0.157381
# Tool Tip Point X                                0.165501         0.100094
# Tool Tip Point Y                               -0.017986        -0.493310
# Tool Tip Point Z                               -0.341068         0.134534
# Tool Orientation X                              0.159703         0.219327
# Tool Orientation Y                             -0.045582        -0.266337
# Tool Orientation Z                             -0.323105         0.348945
# time                                           -0.010848         0.254403
# MachineX                                       -0.116192         0.378979
# MachineY                                       -0.041916        -0.208217
# MachineZ                                       -0.532834        -0.185068
# MachineA                                       -0.376509        -0.088456
# MachineC                                        0.000601        -0.007190
# LoadSpindle                                     0.001348        -0.101397
# TransfX                                        -0.002109        -0.012622
# TransfY                                         0.000098        -0.000290
# TransfZ                                        -0.341024         0.141693
# TransfI                                        -0.003191         0.001555
# TransfJ                                        -0.009238        -0.004678
# TransfK                                        -0.177767        -0.020282
# executionDuration                              -0.001585        -0.050408
# previousExecutionDuration                      -0.001545        -0.048686
# relativeTimetoPreviousCall program number      -0.003074        -0.038326
# timeStamp                                       0.027611         0.380979
# Tool Length                                    -0.016750        -0.180672
# Tool Radius                                          NaN              NaN
# G54-X                                                NaN              NaN
# G54-Y                                                NaN              NaN
# G54-Z                                          -0.000003         0.000064
# G54-A                                          -0.001865        -0.015146
# G54-C                                                NaN              NaN
# ProgNumber                                      0.028051         0.419322
# Blade                                           0.001538         0.009680
# Fx_mean                                        -0.225953         0.553754
# Fy_mean                                        -0.174303         0.528822
# Fz_mean                                        -0.225749         0.403663
# Mz_mean                                        -0.195284         0.601960
# Fc_mean                                        -0.195284         0.601960
# Fa_mean                                        -0.194622         0.554509
# FcN_mean                                       -0.193707         0.554347
# Fres_mean                                      -0.195633         0.554895
# Fx_sigma                                       -0.190141         0.618898
# Fy_sigma                                       -0.162066         0.600430
# Fz_sigma                                       -0.215160         0.439086
# Mz_sigma                                       -0.230317         0.604376
# Fc_sigma                                       -0.230317         0.604376
# Fa_sigma                                       -0.168977         0.620017
# FcN_sigma                                      -0.170890         0.618918
# Fres_sigma                                     -0.171768         0.619945
# Fx_max                                         -0.185436         0.603324
# Fy_max                                         -0.197895         0.589946
# Fz_max                                         -0.199906         0.389607
# Mz_max                                         -0.230403         0.586956
# Fc_max                                         -0.230403         0.586956
# Fa_max                                         -0.199848         0.586444
# FcN_max                                        -0.200000         0.586412
# Fres_max                                       -0.202092         0.587487
# compensation_x                                 -0.491507        -0.208697
# compensation_y                                  0.100737         0.350839
# compensation_z                                  0.213358         0.342789
# tcp_error                                       0.053557        -0.803472
#
#                                            Surface Contact point X  \
# Leading angle                                             0.044703
# Side tilt angle                                           0.104346
# Surface Contact point X                                   1.000000
# Surface contact point Y                                   0.254040
# Surface contact point z                                   0.989458
# Surface Orietation X                                      0.427806
# Surface Orietation Y                                     -0.343062
# Surface Orietation Z                                      0.133139
# Tool Tip Point X                                          0.985773
# Tool Tip Point Y                                          0.247251
# Tool Tip Point Z                                          0.888740
# Tool Orientation X                                        0.905074
# Tool Orientation Y                                       -0.738932
# Tool Orientation Z                                        0.660228
# time                                                     -0.003091
# MachineX                                                 -0.442838
# MachineY                                                 -0.730722
# MachineZ                                                  0.067663
# MachineA                                                  0.032778
# MachineC                                                  0.003928
# LoadSpindle                                               0.068823
# TransfX                                                   0.004181
# TransfY                                                   0.001124
# TransfZ                                                   0.884965
# TransfI                                                  -0.006213
# TransfJ                                                  -0.008880
# TransfK                                                  -0.078537
# executionDuration                                         0.019600
# previousExecutionDuration                                 0.018573
# relativeTimetoPreviousCall program number                 0.012259
# timeStamp                                                -0.181265
# Tool Length                                               0.091582
# Tool Radius                                                    NaN
# G54-X                                                          NaN
# G54-Y                                                          NaN
# G54-Z                                                    -0.000008
# G54-A                                                     0.003619
# G54-C                                                          NaN
# ProgNumber                                               -0.190519
# Blade                                                    -0.001119
# Fx_mean                                                  -0.082274
# Fy_mean                                                  -0.099534
# Fz_mean                                                  -0.054955
# Mz_mean                                                  -0.090935
# Fc_mean                                                  -0.090935
# Fa_mean                                                  -0.099599
# FcN_mean                                                 -0.100338
# Fres_mean                                                -0.099759
# Fx_sigma                                                 -0.142139
# Fy_sigma                                                 -0.159981
# Fz_sigma                                                 -0.064304
# Mz_sigma                                                 -0.100472
# Fc_sigma                                                 -0.100472
# Fa_sigma                                                 -0.166999
# FcN_sigma                                                -0.165628
# Fres_sigma                                               -0.162275
# Fx_max                                                   -0.138027
# Fy_max                                                   -0.168859
# Fz_max                                                   -0.051624
# Mz_max                                                   -0.111889
# Fc_max                                                   -0.111889
# Fa_max                                                   -0.154721
# FcN_max                                                  -0.154705
# Fres_max                                                 -0.150659
# compensation_x                                           -0.081941
# compensation_y                                            0.328870
# compensation_z                                           -0.414188
# tcp_error                                                -0.316711
#
#                                            Surface contact point Y  \
# Leading angle                                            -0.021890
# Side tilt angle                                          -0.292187
# Surface Contact point X                                   0.254040
# Surface contact point Y                                   1.000000
# Surface contact point z                                   0.301308
# Surface Orietation X                                      0.043763
# Surface Orietation Y                                      0.283487
# Surface Orietation Z                                      0.017501
# Tool Tip Point X                                          0.236543
# Tool Tip Point Y                                          0.883460
# Tool Tip Point Z                                          0.230152
# Tool Orientation X                                        0.148159
# Tool Orientation Y                                       -0.029948
# Tool Orientation Z                                       -0.043086
# time                                                     -0.069128
# MachineX                                                 -0.801693
# MachineY                                                  0.217836
# MachineZ                                                  0.506193
# MachineA                                                  0.488975
# MachineC                                                  0.009736
# LoadSpindle                                               0.318407
# TransfX                                                   0.015313
# TransfY                                                   0.007564
# TransfZ                                                   0.226749
# TransfI                                                  -0.004311
# TransfJ                                                  -0.004160
# TransfK                                                  -0.100109
# executionDuration                                         0.079225
# previousExecutionDuration                                 0.075417
# relativeTimetoPreviousCall program number                 0.050875
# timeStamp                                                -0.833041
# Tool Length                                               0.446707
# Tool Radius                                                    NaN
# G54-X                                                          NaN
# G54-Y                                                          NaN
# G54-Z                                                     0.000074
# G54-A                                                     0.017452
# G54-C                                                          NaN
# ProgNumber                                               -0.846536
# Blade                                                    -0.006403
# Fx_mean                                                   0.030636
# Fy_mean                                                   0.046501
# Fz_mean                                                   0.039515
# Mz_mean                                                  -0.151442
# Fc_mean                                                  -0.151442
# Fa_mean                                                   0.022789
# FcN_mean                                                  0.022429
# Fres_mean                                                 0.021798
# Fx_sigma                                                 -0.114674
# Fy_sigma                                                 -0.094148
# Fz_sigma                                                  0.023443
# Mz_sigma                                                 -0.123175
# Fc_sigma                                                 -0.123175
# Fa_sigma                                                 -0.132280
# FcN_sigma                                                -0.128542
# Fres_sigma                                               -0.129383
# Fx_max                                                   -0.113322
# Fy_max                                                   -0.091067
# Fz_max                                                    0.045511
# Mz_max                                                   -0.110740
# Fc_max                                                   -0.110740
# Fa_max                                                   -0.075274
# FcN_max                                                  -0.075046
# Fres_max                                                 -0.074653
# compensation_x                                            0.501848
# compensation_y                                           -0.607133
# compensation_z                                           -0.818098
# tcp_error                                                 0.194033
#
#                                            Surface contact point z  \
# Leading angle                                            -0.019220
# Side tilt angle                                           0.117556
# Surface Contact point X                                   0.989458
# Surface contact point Y                                   0.301308
# Surface contact point z                                   1.000000
# Surface Orietation X                                      0.361661
# Surface Orietation Y                                     -0.330919
# Surface Orietation Z                                      0.209740
# Tool Tip Point X                                          0.963139
# Tool Tip Point Y                                          0.268603
# Tool Tip Point Z                                          0.921952
# Tool Orientation X                                        0.886895
# Tool Orientation Y                                       -0.705259
# Tool Orientation Z                                        0.676587
# time                                                     -0.006601
# MachineX                                                 -0.468799
# MachineY                                                 -0.700805
# MachineZ                                                  0.118282
# MachineA                                                  0.104198
# MachineC                                                  0.004239
# LoadSpindle                                               0.079378
# TransfX                                                   0.004455
# TransfY                                                   0.001468
# TransfZ                                                   0.918702
# TransfI                                                  -0.005163
# TransfJ                                                  -0.008246
# TransfK                                                  -0.080521
# executionDuration                                         0.021542
# previousExecutionDuration                                 0.020421
# relativeTimetoPreviousCall program number                 0.013004
# timeStamp                                                -0.201360
# Tool Length                                               0.103461
# Tool Radius                                                    NaN
# G54-X                                                          NaN
# G54-Y                                                          NaN
# G54-Z                                                     0.000005
# G54-A                                                     0.004056
# G54-C                                                          NaN
# ProgNumber                                               -0.209712
# Blade                                                    -0.001310
# Fx_mean                                                  -0.031359
# Fy_mean                                                  -0.051011
# Fz_mean                                                  -0.009421
# Mz_mean                                                  -0.048754
# Fc_mean                                                  -0.048754
# Fa_mean                                                  -0.049760
# FcN_mean                                                 -0.050528
# Fres_mean                                                -0.049834
# Fx_sigma                                                 -0.093980
# Fy_sigma                                                 -0.113245
# Fz_sigma                                                 -0.017804
# Mz_sigma                                                 -0.050934
# Fc_sigma                                                 -0.050934
# Fa_sigma                                                 -0.120330
# FcN_sigma                                                -0.118809
# Fres_sigma                                               -0.115341
# Fx_max                                                   -0.092122
# Fy_max                                                   -0.121029
# Fz_max                                                   -0.007648
# Mz_max                                                   -0.061229
# Fc_max                                                   -0.061229
# Fa_max                                                   -0.106013
# FcN_max                                                  -0.105976
# Fres_max                                                 -0.101734
# compensation_x                                           -0.030161
# compensation_y                                            0.284957
# compensation_z                                           -0.459667
# tcp_error                                                -0.320816
#
#                                            Surface Orietation X  \
# Leading angle                                      6.941619e-01
# Side tilt angle                                    9.119672e-02
# Surface Contact point X                            4.278062e-01
# Surface contact point Y                            4.376291e-02
# Surface contact point z                            3.616606e-01
# Surface Orietation X                               1.000000e+00
# Surface Orietation Y                              -2.017270e-01
# Surface Orietation Z                              -6.882798e-01
# Tool Tip Point X                                   5.706122e-01
# Tool Tip Point Y                                   2.955276e-02
# Tool Tip Point Z                                   4.314385e-02
# Tool Orientation X                                 5.034166e-01
# Tool Orientation Y                                -3.300832e-01
# Tool Orientation Z                                -2.870373e-02
# time                                               6.957810e-03
# MachineX                                          -2.145849e-01
# MachineY                                          -4.243295e-01
# MachineZ                                          -4.983478e-01
# MachineA                                          -4.527331e-01
# MachineC                                           3.057179e-03
# LoadSpindle                                       -5.246638e-03
# TransfX                                            1.625777e-04
# TransfY                                           -2.733240e-04
# TransfZ                                            4.031493e-02
# TransfI                                           -4.312825e-03
# TransfJ                                           -1.001378e-02
# TransfK                                           -1.666897e-01
# executionDuration                                 -1.191308e-03
# previousExecutionDuration                         -9.580266e-04
# relativeTimetoPreviousCall program number         -1.506207e-03
# timeStamp                                          9.757576e-03
# Tool Length                                       -6.425563e-03
# Tool Radius                                                 NaN
# G54-X                                                       NaN
# G54-Y                                                       NaN
# G54-Z                                              9.483968e-07
# G54-A                                             -6.334679e-04
# G54-C                                                       NaN
# ProgNumber                                         8.946129e-03
# Blade                                              5.453868e-04
# Fx_mean                                           -1.447416e-01
# Fy_mean                                           -1.019108e-01
# Fz_mean                                           -1.549007e-01
# Mz_mean                                           -1.152908e-01
# Fc_mean                                           -1.152908e-01
# Fa_mean                                           -1.214482e-01
# FcN_mean                                          -1.209402e-01
# Fres_mean                                         -1.222194e-01
# Fx_sigma                                          -1.433428e-01
# Fy_sigma                                          -1.230590e-01
# Fz_sigma                                          -1.456013e-01
# Mz_sigma                                          -1.357631e-01
# Fc_sigma                                          -1.357631e-01
# Fa_sigma                                          -1.348277e-01
# FcN_sigma                                         -1.358000e-01
# Fres_sigma                                        -1.318212e-01
# Fx_max                                            -1.425889e-01
# Fy_max                                            -1.652787e-01
# Fz_max                                            -1.330575e-01
# Mz_max                                            -1.374263e-01
# Fc_max                                            -1.374263e-01
# Fa_max                                            -1.558931e-01
# FcN_max                                           -1.559934e-01
# Fres_max                                          -1.529288e-01
# compensation_x                                    -5.352269e-01
# compensation_y                                     3.289154e-01
# compensation_z                                     9.156322e-02
# tcp_error                                         -2.754878e-01
#
#                                            Surface Orietation Y  \
# Leading angle                                          0.023494
# Side tilt angle                                       -0.843636
# Surface Contact point X                               -0.343062
# Surface contact point Y                                0.283487
# Surface contact point z                               -0.330919
# Surface Orietation X                                  -0.201727
# Surface Orietation Y                                   1.000000
# Surface Orietation Z                                  -0.223384
# Tool Tip Point X                                      -0.337501
# Tool Tip Point Y                                       0.411972
# Tool Tip Point Z                                      -0.355709
# Tool Orientation X                                    -0.468900
# Tool Orientation Y                                     0.592414
# Tool Orientation Z                                    -0.529089
# time                                                  -0.251035
# MachineX                                              -0.266162
# MachineY                                               0.380228
# MachineZ                                               0.141156
# MachineA                                               0.072344
# MachineC                                               0.003946
# LoadSpindle                                            0.082924
# TransfX                                                0.009099
# TransfY                                                0.000691
# TransfZ                                               -0.359289
# TransfI                                                0.000672
# TransfJ                                                0.010861
# TransfK                                               -0.021573
# executionDuration                                      0.040653
# previousExecutionDuration                              0.039443
# relativeTimetoPreviousCall program number              0.028842
# timeStamp                                             -0.308507
# Tool Length                                            0.147296
# Tool Radius                                                 NaN
# G54-X                                                       NaN
# G54-Y                                                       NaN
# G54-Z                                                 -0.000026
# G54-A                                                  0.011709
# G54-C                                                       NaN
# ProgNumber                                            -0.337227
# Blade                                                 -0.007309
# Fx_mean                                               -0.267178
# Fy_mean                                               -0.248263
# Fz_mean                                               -0.197357
# Mz_mean                                               -0.294402
# Fc_mean                                               -0.294402
# Fa_mean                                               -0.261781
# FcN_mean                                              -0.261575
# Fres_mean                                             -0.262027
# Fx_sigma                                              -0.285731
# Fy_sigma                                              -0.270729
# Fz_sigma                                              -0.211968
# Mz_sigma                                              -0.292037
# Fc_sigma                                              -0.292037
# Fa_sigma                                              -0.280308
# FcN_sigma                                             -0.280252
# Fres_sigma                                            -0.283358
# Fx_max                                                -0.276966
# Fy_max                                                -0.265370
# Fz_max                                                -0.183794
# Mz_max                                                -0.282265
# Fc_max                                                -0.282265
# Fa_max                                                -0.264731
# FcN_max                                               -0.264846
# Fres_max                                              -0.268922
# compensation_x                                         0.202605
# compensation_y                                        -0.418555
# compensation_z                                        -0.224973
# tcp_error                                              0.721440
#
#                                            Surface Orietation Z  \
# Leading angle                                         -0.850477
# Side tilt angle                                        0.157381
# Surface Contact point X                                0.133139
# Surface contact point Y                                0.017501
# Surface contact point z                                0.209740
# Surface Orietation X                                  -0.688280
# Surface Orietation Y                                  -0.223384
# Surface Orietation Z                                   1.000000
# Tool Tip Point X                                      -0.003190
# Tool Tip Point Y                                      -0.007588
# Tool Tip Point Z                                       0.559383
# Tool Orientation X                                    -0.005599
# Tool Orientation Y                                    -0.120028
# Tool Orientation Z                                     0.500303
# time                                                  -0.000248
# MachineX                                               0.098434
# MachineY                                              -0.039249
# MachineZ                                               0.616748
# MachineA                                               0.511885
# MachineC                                               0.000149
# LoadSpindle                                           -0.000433
# TransfX                                                0.001076
# TransfY                                               -0.000102
# TransfZ                                                0.565348
# TransfI                                                0.003131
# TransfJ                                                0.004654
# TransfK                                                0.106303
# executionDuration                                      0.000614
# previousExecutionDuration                              0.000572
# relativeTimetoPreviousCall program number             -0.000012
# timeStamp                                              0.003930
# Tool Length                                           -0.000440
# Tool Radius                                                 NaN
# G54-X                                                       NaN
# G54-Y                                                       NaN
# G54-Z                                                 -0.000004
# G54-A                                                  0.000888
# G54-C                                                       NaN
# ProgNumber                                             0.004528
# Blade                                                 -0.000981
# Fx_mean                                                0.199580
# Fy_mean                                                0.142403
# Fz_mean                                                0.208427
# Mz_mean                                                0.182155
# Fc_mean                                                0.182155
# Fa_mean                                                0.166256
# FcN_mean                                               0.165422
# Fres_mean                                              0.167353
# Fx_sigma                                               0.174923
# Fy_sigma                                               0.136660
# Fz_sigma                                               0.197831
# Mz_sigma                                               0.208811
# Fc_sigma                                               0.208811
# Fa_sigma                                               0.148660
# FcN_sigma                                              0.150246
# Fres_sigma                                             0.152204
# Fx_max                                                 0.165310
# Fy_max                                                 0.169481
# Fz_max                                                 0.181397
# Mz_max                                                 0.207438
# Fc_max                                                 0.207438
# Fa_max                                                 0.169337
# FcN_max                                                0.169475
# Fres_max                                               0.172555
# compensation_x                                         0.551697
# compensation_y                                        -0.068108
# compensation_z                                        -0.283915
# tcp_error                                             -0.172545
#
#                                            Tool Tip Point X  Tool Tip Point Y  \
# Leading angle                                      0.165501         -0.017986
# Side tilt angle                                    0.100094         -0.493310
# Surface Contact point X                            0.985773          0.247251
# Surface contact point Y                            0.236543          0.883460
# Surface contact point z                            0.963139          0.268603
# Surface Orietation X                               0.570612          0.029553
# Surface Orietation Y                              -0.337501          0.411972
# Surface Orietation Z                              -0.003190         -0.007588
# Tool Tip Point X                                   1.000000          0.235631
# Tool Tip Point Y                                   0.235631          1.000000
# Tool Tip Point Z                                   0.816092          0.237859
# Tool Orientation X                                 0.902166          0.135911
# Tool Orientation Y                                -0.715967          0.000716
# Tool Orientation Z                                 0.583451         -0.075710
# time                                              -0.007583         -0.085302
# MachineX                                          -0.438636         -0.892347
# MachineY                                          -0.745206          0.248786
# MachineZ                                          -0.021631          0.573541
# MachineA                                          -0.058300          0.528941
# MachineC                                           0.004189          0.010749
# LoadSpindle                                        0.061759          0.345538
# TransfX                                            0.004017          0.017002
# TransfY                                            0.000930          0.007955
# TransfZ                                            0.812328          0.233406
# TransfI                                           -0.006545         -0.004467
# TransfJ                                           -0.009643         -0.003251
# TransfK                                           -0.104269         -0.102908
# executionDuration                                  0.018291          0.087007
# previousExecutionDuration                          0.017398          0.082936
# relativeTimetoPreviousCall program number          0.011215          0.056071
# timeStamp                                         -0.164248         -0.921652
# Tool Length                                        0.081818          0.491649
# Tool Radius                                             NaN               NaN
# G54-X                                                   NaN               NaN
# G54-Y                                                   NaN               NaN
# G54-Z                                             -0.000011         -0.000034
# G54-A                                              0.003341          0.019236
# G54-C                                                   NaN               NaN
# ProgNumber                                        -0.173958         -0.939173
# Blade                                             -0.001054         -0.006980
# Fx_mean                                           -0.102619         -0.019864
# Fy_mean                                           -0.109976         -0.000972
# Fz_mean                                           -0.078900          0.003196
# Mz_mean                                           -0.104704         -0.216093
# Fc_mean                                           -0.104704         -0.216093
# Fa_mean                                           -0.113854         -0.028189
# FcN_mean                                          -0.114426         -0.028559
# Fres_mean                                         -0.114129         -0.029276
# Fx_sigma                                          -0.156782         -0.178774
# Fy_sigma                                          -0.168996         -0.155640
# Fz_sigma                                          -0.085882         -0.017253
# Mz_sigma                                          -0.116480         -0.187049
# Fc_sigma                                          -0.116480         -0.187049
# Fa_sigma                                          -0.177665         -0.197672
# FcN_sigma                                         -0.176607         -0.193643
# Fres_sigma                                        -0.172746         -0.194579
# Fx_max                                            -0.152898         -0.176576
# Fy_max                                            -0.184976         -0.152003
# Fz_max                                            -0.072161          0.010784
# Mz_max                                            -0.126679         -0.172994
# Fc_max                                            -0.126679         -0.172994
# Fa_max                                            -0.170280         -0.135097
# FcN_max                                           -0.170292         -0.134850
# Fres_max                                          -0.166024         -0.134490
# compensation_x                                    -0.165772          0.569004
# compensation_y                                     0.361074         -0.682033
# compensation_z                                    -0.362137         -0.911612
# tcp_error                                         -0.337807          0.300773
#
#                                            Tool Tip Point Z  \
# Leading angle                                     -0.341068
# Side tilt angle                                    0.134534
# Surface Contact point X                            0.888740
# Surface contact point Y                            0.230152
# Surface contact point z                            0.921952
# Surface Orietation X                               0.043144
# Surface Orietation Y                              -0.355709
# Surface Orietation Z                               0.559383
# Tool Tip Point X                                   0.816092
# Tool Tip Point Y                                   0.237859
# Tool Tip Point Z                                   1.000000
# Tool Orientation X                                 0.744557
# Tool Orientation Y                                -0.633369
# Tool Orientation Z                                 0.750428
# time                                              -0.007045
# MachineX                                          -0.366436
# MachineY                                          -0.614017
# MachineZ                                           0.344739
# MachineA                                           0.281377
# MachineC                                           0.003690
# LoadSpindle                                        0.069101
# TransfX                                            0.004375
# TransfY                                            0.001214
# TransfZ                                            0.999546
# TransfI                                           -0.003315
# TransfJ                                           -0.005040
# TransfK                                           -0.028659
# executionDuration                                  0.019210
# previousExecutionDuration                          0.018248
# relativeTimetoPreviousCall program number          0.011414
# timeStamp                                         -0.175647
# Tool Length                                        0.090173
# Tool Radius                                             NaN
# G54-X                                                   NaN
# G54-Y                                                   NaN
# G54-Z                                             -0.000021
# G54-A                                              0.003901
# G54-C                                                   NaN
# ProgNumber                                        -0.183482
# Blade                                             -0.001514
# Fx_mean                                            0.047056
# Fy_mean                                            0.009303
# Fz_mean                                            0.070149
# Mz_mean                                            0.023620
# Fc_mean                                            0.023620
# Fa_mean                                            0.018997
# FcN_mean                                           0.018047
# Fres_mean                                          0.019351
# Fx_sigma                                          -0.016589
# Fy_sigma                                          -0.047025
# Fz_sigma                                           0.058604
# Mz_sigma                                           0.032977
# Fc_sigma                                           0.032977
# Fa_sigma                                          -0.048954
# FcN_sigma                                         -0.047047
# Fres_sigma                                        -0.043257
# Fx_max                                            -0.018890
# Fy_max                                            -0.041637
# Fz_max                                             0.060877
# Mz_max                                             0.024465
# Fc_max                                             0.024465
# Fa_max                                            -0.028636
# FcN_max                                           -0.028552
# Fres_max                                          -0.023696
# compensation_x                                     0.192258
# compensation_y                                     0.214523
# compensation_z                                    -0.507302
# tcp_error                                         -0.333355
#
#                                            Tool Orientation X  \
# Leading angle                                        0.159703
# Side tilt angle                                      0.219327
# Surface Contact point X                              0.905074
# Surface contact point Y                              0.148159
# Surface contact point z                              0.886895
# Surface Orietation X                                 0.503417
# Surface Orietation Y                                -0.468900
# Surface Orietation Z                                -0.005599
# Tool Tip Point X                                     0.902166
# Tool Tip Point Y                                     0.135911
# Tool Tip Point Z                                     0.744557
# Tool Orientation X                                   1.000000
# Tool Orientation Y                                  -0.889748
# Tool Orientation Z                                   0.710753
# time                                                 0.091529
# MachineX                                            -0.440369
# MachineY                                            -0.618681
# MachineZ                                            -0.113893
# MachineA                                             0.042772
# MachineC                                             0.002713
# LoadSpindle                                          0.053275
# TransfX                                              0.000564
# TransfY                                              0.001496
# TransfZ                                              0.738438
# TransfI                                             -0.004119
# TransfJ                                             -0.012252
# TransfK                                             -0.051025
# executionDuration                                    0.005483
# previousExecutionDuration                            0.004752
# relativeTimetoPreviousCall program number            0.004250
# timeStamp                                           -0.131755
# Tool Length                                          0.078590
# Tool Radius                                               NaN
# G54-X                                                     NaN
# G54-Y                                                     NaN
# G54-Z                                               -0.000002
# G54-A                                                0.000141
# G54-C                                                     NaN
# ProgNumber                                          -0.123252
# Blade                                                0.001494
# Fx_mean                                             -0.074161
# Fy_mean                                             -0.089386
# Fz_mean                                             -0.061677
# Mz_mean                                             -0.083266
# Fc_mean                                             -0.083266
# Fa_mean                                             -0.088923
# FcN_mean                                            -0.089557
# Fres_mean                                           -0.089316
# Fx_sigma                                            -0.124296
# Fy_sigma                                            -0.140308
# Fz_sigma                                            -0.065981
# Mz_sigma                                            -0.102935
# Fc_sigma                                            -0.102935
# Fa_sigma                                            -0.146014
# FcN_sigma                                           -0.144859
# Fres_sigma                                          -0.142597
# Fx_max                                              -0.121166
# Fy_max                                              -0.150839
# Fz_max                                              -0.052034
# Mz_max                                              -0.119316
# Fc_max                                              -0.119316
# Fa_max                                              -0.139690
# FcN_max                                             -0.139564
# Fres_max                                            -0.136049
# compensation_x                                      -0.224639
# compensation_y                                       0.289297
# ...
# Mz_sigma                                   0.970174  0.970174  0.919979
# Fc_sigma                                   0.970174  0.970174  0.919979
# Fa_sigma                                   0.929176  0.929176  0.981858
# FcN_sigma                                  0.929808  0.929808  0.983048
# Fres_sigma                                 0.931473  0.931473  0.982466
# Fx_max                                     0.923048  0.923048  0.948533
# Fy_max                                     0.921623  0.921623  0.990215
# Fz_max                                     0.661526  0.661526  0.698521
# Mz_max                                     1.000000  1.000000  0.933542
# Fc_max                                     1.000000  1.000000  0.933542
# Fa_max                                     0.933542  0.933542  1.000000
# FcN_max                                    0.933298  0.933298  0.999993
# Fres_max                                   0.935299  0.935299  0.999715
# compensation_x                             0.026866  0.026866  0.033098
# compensation_y                             0.050073  0.050073 -0.016008
# compensation_z                             0.110213  0.110213  0.093235
# tcp_error                                 -0.468764 -0.468764 -0.439919
#
#                                             FcN_max  Fres_max  compensation_x  \
# Leading angle                             -0.200000 -0.202092       -0.491507
# Side tilt angle                            0.586412  0.587487       -0.208697
# Surface Contact point X                   -0.154705 -0.150659       -0.081941
# Surface contact point Y                   -0.075046 -0.074653        0.501848
# Surface contact point z                   -0.105976 -0.101734       -0.030161
# Surface Orietation X                      -0.155993 -0.152929       -0.535227
# Surface Orietation Y                      -0.264846 -0.268922        0.202605
# Surface Orietation Z                       0.169475  0.172555        0.551697
# Tool Tip Point X                          -0.170292 -0.166024       -0.165772
# Tool Tip Point Y                          -0.134850 -0.134490        0.569004
# Tool Tip Point Z                          -0.028552 -0.023696        0.192258
# Tool Orientation X                        -0.139564 -0.136049       -0.224639
# Tool Orientation Y                         0.230609  0.227527        0.136049
# Tool Orientation Z                         0.016524  0.020061        0.121085
# time                                       0.359358  0.359005       -0.158003
# MachineX                                   0.138187  0.137477       -0.319152
# MachineY                                   0.097606  0.093888        0.550140
# MachineZ                                   0.015709  0.017169        0.983562
# MachineA                                   0.102106  0.102483        0.827119
# MachineC                                  -0.074817 -0.075815        0.012450
# LoadSpindle                                0.057822  0.058114        0.223609
# TransfX                                   -0.119478 -0.121347        0.019752
# TransfY                                    0.009466  0.009938        0.003525
# TransfZ                                   -0.021131 -0.016266        0.195398
# TransfI                                    0.000381  0.000317       -0.001640
# TransfJ                                    0.001546  0.001512        0.002301
# TransfK                                    0.033865  0.031790       -0.062515
# executionDuration                          0.011883  0.011871        0.037575
# previousExecutionDuration                  0.006506  0.006620        0.035909
# relativeTimetoPreviousCall program number  0.016702  0.016112        0.024147
# timeStamp                                  0.026908  0.026675       -0.567992
# Tool Length                               -0.108236 -0.110000        0.352586
# Tool Radius                                     NaN       NaN             NaN
# G54-X                                           NaN       NaN             NaN
# G54-Y                                           NaN       NaN             NaN
# G54-Z                                      0.000024  0.000023       -0.000045
# G54-A                                     -0.129230 -0.131340        0.021070
# G54-C                                           NaN       NaN             NaN
# ProgNumber                                 0.045214  0.045241       -0.537587
# Blade                                      0.128839  0.130944       -0.014049
# Fx_mean                                    0.962778  0.964706        0.093319
# Fy_mean                                    0.962633  0.964826        0.071282
# Fz_mean                                    0.727323  0.729222        0.115785
# Mz_mean                                    0.872155  0.873250        0.001064
# Fc_mean                                    0.872155  0.873250        0.001064
# Fa_mean                                    0.974796  0.976672        0.071853
# FcN_mean                                   0.974874  0.976748        0.071209
# Fres_mean                                  0.975055  0.976936        0.071978
# Fx_sigma                                   0.970012  0.969891        0.009683
# Fy_sigma                                   0.985552  0.985633        0.004892
# Fz_sigma                                   0.767125  0.768997        0.103045
# Mz_sigma                                   0.919711  0.921383        0.027378
# Fc_sigma                                   0.919711  0.921383        0.027378
# Fa_sigma                                   0.981820  0.981289       -0.008316
# FcN_sigma                                  0.983018  0.982542       -0.005637
# Fres_sigma                                 0.982446  0.982410       -0.005802
# Fx_max                                     0.948291  0.947492       -0.008893
# Fy_max                                     0.990256  0.989725        0.034012
# Fz_max                                     0.698658  0.700616        0.124314
# Mz_max                                     0.933298  0.935299        0.026866
# Fc_max                                     0.933298  0.935299        0.026866
# Fa_max                                     0.999993  0.999715        0.033098
# FcN_max                                    1.000000  0.999728        0.033391
# Fres_max                                   0.999728  1.000000        0.033986
# compensation_x                             0.033391  0.033986        1.000000
# compensation_y                            -0.016378 -0.014306       -0.751852
# compensation_z                             0.092903  0.091203       -0.714237
# tcp_error                                 -0.439817 -0.443659        0.213479
#
#                                            compensation_y  compensation_z  \
# Leading angle                                    0.100737        0.213358
# Side tilt angle                                  0.350839        0.342789
# Surface Contact point X                          0.328870       -0.414188
# Surface contact point Y                         -0.607133       -0.818098
# Surface contact point z                          0.284957       -0.459667
# Surface Orietation X                             0.328915        0.091563
# Surface Orietation Y                            -0.418555       -0.224973
# Surface Orietation Z                            -0.068108       -0.283915
# Tool Tip Point X                                 0.361074       -0.362137
# Tool Tip Point Y                                -0.682033       -0.911612
# Tool Tip Point Z                                 0.214523       -0.507302
# Tool Orientation X                               0.289297       -0.302048
# Tool Orientation Y                              -0.267840        0.181777
# Tool Orientation Z                               0.191553       -0.228510
# time                                             0.012635        0.097068
# MachineX                                         0.565913        0.868802
# MachineY                                        -0.854272       -0.192244
# MachineZ                                        -0.644208       -0.745888
# MachineA                                        -0.811627       -0.740339
# MachineC                                        -0.007308       -0.012046
# LoadSpindle                                     -0.276719       -0.326573
# TransfX                                         -0.011201       -0.017638
# TransfY                                         -0.006000       -0.007165
# TransfZ                                          0.215710       -0.504391
# TransfI                                         -0.000054        0.003952
# TransfJ                                         -0.000687        0.003526
# TransfK                                          0.057429        0.098575
# executionDuration                               -0.052529       -0.072418
# previousExecutionDuration                       -0.049672       -0.068912
# relativeTimetoPreviousCall program number       -0.034899       -0.046462
# timeStamp                                        0.726342        0.855465
# Tool Length                                     -0.419184       -0.476169
# Tool Radius                                           NaN             NaN
# G54-X                                                 NaN             NaN
# G54-Y                                                 NaN             NaN
# G54-Z                                            0.000018        0.000034
# G54-A                                           -0.013851       -0.019173
# G54-C                                                 NaN             NaN
# ProgNumber                                       0.704855        0.852911
# Blade                                            0.004616        0.008029
# Fx_mean                                         -0.075013       -0.025193
# Fy_mean                                         -0.092108       -0.021561
# Fz_mean                                         -0.077335       -0.053903
# Mz_mean                                          0.086697        0.143834
# Fc_mean                                          0.086697        0.143834
# Fa_mean                                         -0.073504       -0.005772
# FcN_mean                                        -0.073452       -0.005089
# Fres_mean                                       -0.072740       -0.005114
# Fx_sigma                                         0.025385        0.124583
# Fy_sigma                                         0.001743        0.119773
# Fz_sigma                                        -0.068498       -0.034392
# Mz_sigma                                         0.058662        0.114774
# Fc_sigma                                         0.058662        0.114774
# Fa_sigma                                         0.030651        0.152498
# FcN_sigma                                        0.027799        0.148463
# Fres_sigma                                       0.031093        0.148320
# Fx_max                                           0.035215        0.130514
# Fy_max                                          -0.014610        0.108216
# Fz_max                                          -0.093255       -0.063203
# Mz_max                                           0.050073        0.110213
# Fc_max                                           0.050073        0.110213
# Fa_max                                          -0.016008        0.093235
# FcN_max                                         -0.016378        0.092903
# Fres_max                                        -0.014306        0.091203
# compensation_x                                  -0.751852       -0.714237
# compensation_y                                   1.000000        0.669760
# compensation_z                                   0.669760        1.000000
# tcp_error                                       -0.470710       -0.194588
#
#                                            tcp_error
# Leading angle                               0.053557
# Side tilt angle                            -0.803472
# Surface Contact point X                    -0.316711
# Surface contact point Y                     0.194033
# Surface contact point z                    -0.320816
# Surface Orietation X                       -0.275488
# Surface Orietation Y                        0.721440
# Surface Orietation Z                       -0.172545
# Tool Tip Point X                           -0.337807
# Tool Tip Point Y                            0.300773
# Tool Tip Point Z                           -0.333355
# Tool Orientation X                         -0.299196
# Tool Orientation Y                          0.256170
# Tool Orientation Z                         -0.323019
# time                                       -0.129789
# MachineX                                   -0.243288
# MachineY                                    0.467548
# MachineZ                                    0.134266
# MachineA                                    0.213672
# MachineC                                    0.014974
# LoadSpindle                                 0.082544
# TransfX                                     0.027253
# TransfY                                    -0.000300
# TransfZ                                    -0.344044
# TransfI                                    -0.002325
# TransfJ                                     0.002869
# TransfK                                     0.135099
# executionDuration                           0.025799
# previousExecutionDuration                   0.024766
# relativeTimetoPreviousCall program number   0.023907
# timeStamp                                  -0.292136
# Tool Length                                 0.172483
# Tool Radius                                      NaN
# G54-X                                            NaN
# G54-Y                                            NaN
# G54-Z                                      -0.000034
# G54-A                                       0.025999
# G54-C                                            NaN
# ProgNumber                                 -0.306195
# Blade                                      -0.021938
# Fx_mean                                    -0.435166
# Fy_mean                                    -0.417816
# Fz_mean                                    -0.320611
# Mz_mean                                    -0.471303
# Fc_mean                                    -0.471303
# Fa_mean                                    -0.435164
# FcN_mean                                   -0.435088
# Fres_mean                                  -0.435557
# Fx_sigma                                   -0.469412
# Fy_sigma                                   -0.453162
# Fz_sigma                                   -0.346715
# Mz_sigma                                   -0.478512
# Fc_sigma                                   -0.478512
# Fa_sigma                                   -0.464767
# FcN_sigma                                  -0.464177
# Fres_sigma                                 -0.468497
# Fx_max                                     -0.455095
# Fy_max                                     -0.434904
# Fz_max                                     -0.304809
# Mz_max                                     -0.468764
# Fc_max                                     -0.468764
# Fa_max                                     -0.439919
# FcN_max                                    -0.439817
# Fres_max                                   -0.443659
# compensation_x                              0.213479
# compensation_y                             -0.470710
# compensation_z                             -0.194588
# tcp_error                                   1.000000

# %%
#sns.pairplot(df[['Leading angle','Side tilt angle', 'Surface Contact point X', 'Surface contact point Y', 'Surface contact point z','Surface Orietation X','Surface Orietation Y','Tool Tip Point X','Surface Orietation Z', 'Tool Tip Point Y', 'Tool Tip Point Z', 'Tool Orientation X','Tool Orientation Y', 'Tool Orientation Z','TransfX','TransfY','TransfZ','TransfI','TransfJ','TransfK','MachineX', 'MachineY', 'MachineZ', 'MachineA', 'MachineC']])

# %%
# features
X = df[['Leading angle','Side tilt angle', 'Surface Contact point X', 'Surface contact point Y', 'Surface contact point z',
        'Surface Orietation X','Surface Orietation Y','Tool Tip Point X','Surface Orietation Z', 'Tool Tip Point Y', 'Tool Tip Point Z', 'Tool Orientation X',
       'Tool Orientation Y', 'Tool Orientation Z','TransfX','TransfY','TransfZ','TransfI','TransfJ','TransfK']].copy(deep=True)

feature_list = X.columns
y = df[['MachineX', 'MachineY', 'MachineZ', 'MachineA', 'MachineC']].copy(deep=True)

X = X.to_numpy()
y = y.to_numpy()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
print('Training Features Shape:', X_train.shape)
print('Training Labels Shape:', y_train.shape)
print('Testing Features Shape:', X_test.shape)
print('Testing Labels Shape:', y_test.shape)
# Out:
# Training Features Shape: (1129021, 20)
# Training Labels Shape: (1129021, 5)
# Testing Features Shape: (556085, 20)
# Testing Labels Shape: (556085, 5)

# %%
model_gb = GradientBoostingRegressor(n_estimators=10)

wrapper =  MultiOutputRegressor(model_gb)

wrapper.fit(X_train,y_train)
# Out:
# MultiOutputRegressor(estimator=GradientBoostingRegressor(n_estimators=10))

# %%
# Import tools needed for visualization
""""
# Pull out one tree from the forest
tree = wrapper.estimators_[5]
# Export the image to a dot file
export_graphviz(tree, out_file = 'full_tree.dot', feature_names = feature_list, rounded = True, precision = 1)
# Use dot file to create a graph
(graph, ) = pydot.graph_from_dot_file('full_tree.dot')
# Write graph to a png file
graph.write_png('full_tree.png')
"""
# Out:
# '"\n# Pull out one tree from the forest\ntree = wrapper.estimators_[5]\n# Export the image to a dot file\nexport_graphviz(tree, out_file = \'full_tree.dot\', feature_names = feature_list, rounded = True, precision = 1)\n# Use dot file to create a graph\n(graph, ) = pydot.graph_from_dot_file(\'full_tree.dot\')\n# Write graph to a png file\ngraph.write_png(\'full_tree.png\')\n'

# %%
# Make predictions on test data
predictions = wrapper.predict(X_test)
# Performance metrics
errors = abs(predictions - y_test)
sq_error = errors**2

print('Metrics for Random Forest Trained on Full Features')
print('Average absolute error:', round(np.mean(errors), 2))
print('Root mean square error:', round(np.sqrt(np.mean(sq_error)), 2))
# Out:
# Metrics for Random Forest Trained on Full Features
# Average absolute error: 11.02
# Root mean square error: 22.47

# %%
def importance(i):
    # Get numerical feature importances
    estimator = wrapper.estimators_[i]
    importances = list(estimator.feature_importances_)

    # List of tuples with variable and importance
    feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]

    # Sort the feature importances by most important first
    feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)

    # Print out the feature and importances 
    [print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
    
    # Reset style 
    plt.style.use('fivethirtyeight')

    # list of x locations for plotting
    x_values = list(range(len(importances)))

    # Make a bar chart
    plt.bar(x_values, importances, orientation = 'vertical', color = 'r', edgecolor = 'k', linewidth = 1.2)

    # Tick labels for x axis
    plt.xticks(x_values, feature_list, rotation='vertical')

    # Axis labels and title
    plt.ylabel('Importance'); plt.xlabel('Variable'); plt.title('Variable Importances');
    
    # List of features sorted from most to least important
    sorted_importances = [importance[1] for importance in feature_importances]
    sorted_features = [importance[0] for importance in feature_importances]

    # Cumulative importances
    cumulative_importances = np.cumsum(sorted_importances)

    # Make a line graph
    plt.plot(x_values, cumulative_importances, 'g-')

    # Draw line at 95% of importance retained
    plt.hlines(y = 0.95, xmin=0, xmax=len(sorted_importances), color = 'r', linestyles = 'dashed')

    # Format x ticks and labels
    plt.xticks(x_values, sorted_features, rotation = 'vertical')

    # Axis labels and title
    plt.xlabel('Variable'); plt.ylabel('Cumulative Importance'); plt.title('Cumulative Importances');
    plt.figure(i)
    plt.pause(0.5)
    # Find number of features for cumulative importance of 95%
    # Add 1 because Python is zero-indexed
    print('Number of features for 95% importance:', np.where(cumulative_importances > 0.95)[0][0] + 1)
    
    return feature_importances

# %%
feature_importances = []

# %%
for i in np.arange(0,y_train.shape[1]):
    feature_importances.append([feature[0] for feature in importance(i)[0:6]])
# Out:
# Variable: Tool Tip Point Y     Importance: 0.83
# Variable: Tool Orientation X   Importance: 0.13
# Variable: Tool Tip Point X     Importance: 0.02
# Variable: Leading angle        Importance: 0.01
# Variable: Surface contact point Y Importance: 0.01
# Variable: Side tilt angle      Importance: 0.0
# Variable: Surface Contact point X Importance: 0.0
# Variable: Surface contact point z Importance: 0.0
# Variable: Surface Orietation X Importance: 0.0
# Variable: Surface Orietation Y Importance: 0.0
# Variable: Surface Orietation Z Importance: 0.0
# Variable: Tool Tip Point Z     Importance: 0.0
# Variable: Tool Orientation Y   Importance: 0.0
# Variable: Tool Orientation Z   Importance: 0.0
# Variable: TransfX              Importance: 0.0
# Variable: TransfY              Importance: 0.0
# Variable: TransfZ              Importance: 0.0
# Variable: TransfI              Importance: 0.0
# Variable: TransfJ              Importance: 0.0
# Variable: TransfK              Importance: 0.0
# Number of features for 95% importance: 2
# Variable: Tool Tip Point X     Importance: 0.62
# Variable: Tool Tip Point Y     Importance: 0.2
# Variable: Tool Orientation Z   Importance: 0.07
# Variable: Surface Contact point X Importance: 0.05
# Variable: Surface contact point Y Importance: 0.02
# Variable: Side tilt angle      Importance: 0.01
# Variable: Leading angle        Importance: 0.0
# Variable: Surface contact point z Importance: 0.0
# Variable: Surface Orietation X Importance: 0.0
# Variable: Surface Orietation Y Importance: 0.0
# Variable: Surface Orietation Z Importance: 0.0
# Variable: Tool Tip Point Z     Importance: 0.0
# Variable: Tool Orientation X   Importance: 0.0
# Variable: Tool Orientation Y   Importance: 0.0
# Variable: TransfX              Importance: 0.0
# Variable: TransfY              Importance: 0.0
# Variable: TransfZ              Importance: 0.0
# Variable: TransfI              Importance: 0.0
# Variable: TransfJ              Importance: 0.0
# Variable: TransfK              Importance: 0.0
# Number of features for 95% importance: 5
# Variable: Surface Orietation Z Importance: 0.38
# Variable: Tool Tip Point Y     Importance: 0.33
# Variable: Surface contact point Y Importance: 0.15
# Variable: Surface Orietation X Importance: 0.05
# Variable: Tool Orientation Z   Importance: 0.03
# Variable: Tool Tip Point X     Importance: 0.02
# Variable: Surface Contact point X Importance: 0.01
# Variable: Surface Orietation Y Importance: 0.01
# Variable: Tool Orientation Y   Importance: 0.01
# Variable: Leading angle        Importance: 0.0
# Variable: Side tilt angle      Importance: 0.0
# Variable: Surface contact point z Importance: 0.0
# Variable: Tool Tip Point Z     Importance: 0.0
# Variable: Tool Orientation X   Importance: 0.0
# Variable: TransfX              Importance: 0.0
# Variable: TransfY              Importance: 0.0
# Variable: TransfZ              Importance: 0.0
# Variable: TransfI              Importance: 0.0
# Variable: TransfJ              Importance: 0.0
# Variable: TransfK              Importance: 0.0
# Number of features for 95% importance: 6
# Variable: Tool Tip Point Y     Importance: 0.46
# Variable: Surface Orietation X Importance: 0.22
# Variable: Surface contact point Y Importance: 0.15
# Variable: Surface Orietation Z Importance: 0.11
# Variable: Tool Orientation Z   Importance: 0.05
# Variable: Leading angle        Importance: 0.01
# Variable: TransfK              Importance: 0.01
# Variable: Side tilt angle      Importance: 0.0
# Variable: Surface Contact point X Importance: 0.0
# Variable: Surface contact point z Importance: 0.0
# Variable: Surface Orietation Y Importance: 0.0
# Variable: Tool Tip Point X     Importance: 0.0
# Variable: Tool Tip Point Z     Importance: 0.0
# Variable: Tool Orientation X   Importance: 0.0
# Variable: Tool Orientation Y   Importance: 0.0
# Variable: TransfX              Importance: 0.0
# Variable: TransfY              Importance: 0.0
# Variable: TransfZ              Importance: 0.0
# Variable: TransfI              Importance: 0.0
# Variable: TransfJ              Importance: 0.0
# Number of features for 95% importance: 5
# Variable: TransfX              Importance: 0.67
# Variable: TransfY              Importance: 0.32
# Variable: Leading angle        Importance: 0.0
# Variable: Side tilt angle      Importance: 0.0
# Variable: Surface Contact point X Importance: 0.0
# Variable: Surface contact point Y Importance: 0.0
# Variable: Surface contact point z Importance: 0.0
# Variable: Surface Orietation X Importance: 0.0
# Variable: Surface Orietation Y Importance: 0.0
# Variable: Tool Tip Point X     Importance: 0.0
# Variable: Surface Orietation Z Importance: 0.0
# Variable: Tool Tip Point Y     Importance: 0.0
# Variable: Tool Tip Point Z     Importance: 0.0
# Variable: Tool Orientation X   Importance: 0.0
# Variable: Tool Orientation Y   Importance: 0.0
# Variable: Tool Orientation Z   Importance: 0.0
# Variable: TransfZ              Importance: 0.0
# Variable: TransfI              Importance: 0.0
# Variable: TransfJ              Importance: 0.0
# Variable: TransfK              Importance: 0.0
# Number of features for 95% importance: 2

# %%
feature_importances
# Out:
# [['Tool Tip Point Y',
#   'Tool Orientation X',
#   'Tool Tip Point X',
#   'Leading angle',
#   'Surface contact point Y',
#   'Side tilt angle'],
#  ['Tool Tip Point X',
#   'Tool Tip Point Y',
#   'Tool Orientation Z',
#   'Surface Contact point X',
#   'Surface contact point Y',
#   'Side tilt angle'],
#  ['Surface Orietation Z',
#   'Tool Tip Point Y',
#   'Surface contact point Y',
#   'Surface Orietation X',
#   'Tool Orientation Z',
#   'Tool Tip Point X'],
#  ['Tool Tip Point Y',
#   'Surface Orietation X',
#   'Surface contact point Y',
#   'Surface Orietation Z',
#   'Tool Orientation Z',
#   'Leading angle'],
#  ['TransfX',
#   'TransfY',
#   'Leading angle',
#   'Side tilt angle',
#   'Surface Contact point X',
#   'Surface contact point Y']]

# %%
# Extract the names of the most important features
important_feature_names = list(set().union(feature_importances[0],feature_importances[1],feature_importances[2],feature_importances[3],feature_importances[4]))
important_feature_names
# Out:
# ['Surface contact point Y',
#  'Surface Orietation X',
#  'Surface Contact point X',
#  'Side tilt angle',
#  'Surface Orietation Z',
#  'Leading angle',
#  'TransfX',
#  'Tool Tip Point Y',
#  'Tool Orientation X',
#  'Tool Tip Point X',
#  'TransfY',
#  'Tool Orientation Z']

# %%
feature_list = list(feature_list)

# %%
# Find the columns of the most important features
important_indices = [feature_list.index(feature) for feature in important_feature_names]

# Create training and testing sets with only the important features
X_train_important = X_train[:, important_indices]
X_test_important = X_test[:, important_indices]

# Sanity check on operations
print('Important train features shape:', X_train_important.shape)
print('Important test features shape:', X_test_important.shape)
# Out:
# Important train features shape: (1129021, 12)
# Important test features shape: (556085, 12)

# %%
# Train the expanded model on only the important features
wrapper.fit(X_train_important, y_train)
# Out:
# MultiOutputRegressor(estimator=GradientBoostingRegressor(n_estimators=10))

# %%
# Import tools needed for visualization
"""
# Pull out one tree from the forest
tree = wrapper.estimators_[5]
# Export the image to a dot file
export_graphviz(tree, out_file = 'imp_tree.dot', feature_names = feature_list, rounded = True, precision = 1)
# Use dot file to create a graph
(graph, ) = pydot.graph_from_dot_file('imp_tree.dot')
# Write graph to a png file
graph.write_png('imp_tree.png')
"""
# Out:
# "\n# Pull out one tree from the forest\ntree = wrapper.estimators_[5]\n# Export the image to a dot file\nexport_graphviz(tree, out_file = 'imp_tree.dot', feature_names = feature_list, rounded = True, precision = 1)\n# Use dot file to create a graph\n(graph, ) = pydot.graph_from_dot_file('imp_tree.dot')\n# Write graph to a png file\ngraph.write_png('imp_tree.png')\n"

# %%
# Make predictions on test data
predictions = wrapper.predict(X_test_important)

# Performance metrics
errors = abs(predictions - y_test)
sq_error = errors**2

print('Metrics for Random Forest Trained on Full Features')
print('Average absolute error:', round(np.mean(errors), 2))
print('Root mean square error:', round(np.sqrt(np.mean(sq_error)), 2))
# Out:
# Metrics for Random Forest Trained on Full Features
# Average absolute error: 11.03
# Root mean square error: 22.48

# %%
from sklearn.model_selection import RandomizedSearchCV

loss = ['ls','huber']
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)]
# Number of features to consider at every split
learning_rate=[0.01,0.05, 0.1, 0.2, 0.5, 0.9]

max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 500, num = 11)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]

criterion = ['mse', 'lad']
# Create the random grid
random_grid = {'Wrapper__estimator__n_estimators': n_estimators,
               'Wrapper__estimator__loss':loss,
               'learning_rate':learning_rate,
               'Wrapper__estimator__max_features': max_features,
               'max_depth': max_depth,
               'Wrapper__estimator__min_samples_split': min_samples_split,
               'Wrapper__estimator__min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap,
               'criterion':criterion}
print(random_grid)
# Out:
# {'Wrapper__estimator__n_estimators': [200, 400, 600, 800, 1000, 1200, 1400, 1600, 1800, 2000], 'Wrapper__estimator__loss': ['ls', 'huber'], 'learning_rate': [0.01, 0.05, 0.1, 0.2, 0.5, 0.9], 'Wrapper__estimator__max_features': ['auto', 'sqrt'], 'max_depth': [10, 59, 108, 157, 206, 255, 304, 353, 402, 451, 500, None], 'Wrapper__estimator__min_samples_split': [2, 5, 10], 'Wrapper__estimator__min_samples_leaf': [1, 2, 4], 'bootstrap': [True, False], 'criterion': ['mse', 'lad']}

# %%
from sklearn.pipeline import Pipeline

steps = [('Wrapper',MultiOutputRegressor(GradientBoostingRegressor()))]

pipeline = Pipeline(steps)

# %%
pipeline.get_params().keys()
# Out:
# dict_keys(['memory', 'steps', 'verbose', 'Wrapper', 'Wrapper__estimator__alpha', 'Wrapper__estimator__ccp_alpha', 'Wrapper__estimator__criterion', 'Wrapper__estimator__init', 'Wrapper__estimator__learning_rate', 'Wrapper__estimator__loss', 'Wrapper__estimator__max_depth', 'Wrapper__estimator__max_features', 'Wrapper__estimator__max_leaf_nodes', 'Wrapper__estimator__min_impurity_decrease', 'Wrapper__estimator__min_impurity_split', 'Wrapper__estimator__min_samples_leaf', 'Wrapper__estimator__min_samples_split', 'Wrapper__estimator__min_weight_fraction_leaf', 'Wrapper__estimator__n_estimators', 'Wrapper__estimator__n_iter_no_change', 'Wrapper__estimator__random_state', 'Wrapper__estimator__subsample', 'Wrapper__estimator__tol', 'Wrapper__estimator__validation_fraction', 'Wrapper__estimator__verbose', 'Wrapper__estimator__warm_start', 'Wrapper__estimator', 'Wrapper__n_jobs'])

# %%
rf_random = RandomizedSearchCV(estimator=, param_distributions=random_grid,
                              n_iter = 100, scoring='neg_mean_absolute_error', 
                              cv = 3, verbose=2, random_state=42, n_jobs=-1,
                              return_train_score=True)

# Fit the random search model
rf_random.fit(X_train, y_train)
# Out:
#   File "<ipython-input-174-fc6bade4ad3e>", line 1
#     rf_random = RandomizedSearchCV(estimator=, param_distributions=random_grid,
#                                              ^
# SyntaxError: invalid syntax

# %%
rf_random.best_params_

# %%
rf_random.cv_results_
